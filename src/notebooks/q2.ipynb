# %% [markdown]
# # <center> BLG 527E Machine Learning Homework 2

# %% [markdown]
# ## Question 2 - PCA

# %% [markdown]
# PCA can be calculated by following these steps
# 1. Standardize the data
#
#    $ x_{ij}' = \frac{x_{ij} - \mu_j}{\sigma_j} $
#
# 2. Compute covariance matrix
#
#    $  C = \frac{1}{n - 1} X'^{\top} X' $
#
# 3. Compute eigenvalues and eigenvectors
#
#    $ C v_k = \lambda_k v_k $
#
# 4. Sort and select principal compenents
#
#    $ V_k = \text{Sorted eigenvectors corresponding to top } k \text{ eigenvalues} $
#
# 5. Transform the data
#
#    $ Z = X' V_k $

# %%
import os
import sys
import numpy as np

# Add upper folder to pythons' path to reach custom functions
if '..' not in sys.path:
    sys.path.insert(0, '..')

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Read the data
data = np.loadtxt('../../dataset/data.txt', delimiter=",")
X = data[:, :-1]  
y = data[:, -1]

# %%
data.shape
# Out:
# (3823, 65)

# %%
from pca import PCA

# %%
pca = PCA(n_components=2)
pca.fit_transform(X)
pca.visualize(y)
